# %%
#import libraries
import pandas as pd
import numpy as np

# %%
location = "Documents/DataBootcamp/diamonds.CSV"
df = pd.read_csv(location)
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9              10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.tail(3)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
#load data without headers

# %%
#load data without headers

# %%
#add headers after data load

# %%
#load data without headers
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-e20366e82f7f> in <module>()
#       2
#       3 location2 = "datasets/smallgrades.csv"
# ----> 4 df_nohead = pd.read_csv(location2, header=None) #try w/o header=None
#       5 df_nohead.head()
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
#descriptive statistics

# %%
#load data without headers

location2 = #load data without headers

location2 = "datasets/smallgrades.csv"df_nohead = pd.read_csv(location2, header=None) #try w/o header=None
df_nohead.head(
df_nohead = pd.read_csv(location2, header=None) #try w/o header=None
df_nohead.head
(
# Out:
#   File "<ipython-input-25-844a5c294c7e>", line 5
#     df_nohead.head(
#                    ^
# SyntaxError: unexpected EOF while parsing

# %%
#load data without headers

location = "Documents/DataBootcamp/diamonds.csv"
df_nohead = pd.read_csv(location2, header=None) #try w/o header=None
df_nohead.head(
df_nohead = pd.read_csv(location2, header=None) #try w/o header=None
df_nohead.head
# Out:
#   File "<ipython-input-27-5f6314541f42>", line 7
#     df_nohead.head
#             ^
# SyntaxError: invalid syntax

# %%
#descriptive statistics
#load diamonds.csv file

location = "Documents/DataBootcamp/diamonds.CSV"
df = pd.read_csv(location)

df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
#load data without headers
location = "Documents/DataBootcamp/diamonds.CSV"

# %%
type(1)
# Out:
# int

# %%
print(4)
# Out:
# 4

# %%
def addNum(x,y):
    return x+y

# %%
#df.groupby(['price'
]).mean()

# %%
#df.groupby(['price']).mean()
location = Documents/DataBootcamp/diamonds.CSV
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-ca9481115a76> in <module>()
#       1 #df.groupby(['price']).mean()
# ----> 2 location = Documents/DataBootcamp/diamonds.CSV
#       3
#
# NameError: name 'Documents' is not defined

# %%
#df.groupby({"price"}

# %%
#descriptive statistics
#load diamonds.csv file

location = "Documents/DataBootcamp/diamonds.CSV"
df = pd.read_csv(location)

#df.groupby(["price"]).mean()

# %%
#pivot table
pd.pivot_table(df, index=["price"])
# Out:
#          Unnamed: 0     carat      depth      table         x         y  \
# price
# 326        1.500000  0.220000  60.650000  58.000000  3.920000  3.910000
# 327        3.000000  0.230000  56.900000  65.000000  4.050000  4.070000
# 334        4.000000  0.290000  62.400000  58.000000  4.200000  4.230000
# 335        5.000000  0.310000  63.300000  58.000000  4.340000  4.350000
# 336        6.500000  0.240000  62.550000  57.000000  3.945000  3.970000
# 337        8.500000  0.240000  63.500000  58.000000  3.970000  3.945000
# 338       10.000000  0.230000  59.400000  61.000000  4.000000  4.050000
# 339       11.000000  0.300000  64.000000  55.000000  4.250000  4.280000
# 340       12.000000  0.230000  62.800000  56.000000  3.930000  3.900000
# 342       13.000000  0.220000  60.400000  61.000000  3.880000  3.840000
# 344       14.000000  0.310000  62.200000  54.000000  4.350000  4.370000
# 345       15.500000  0.260000  60.550000  60.000000  4.085000  4.085000
# ...

# %%
df["carat"].unique()
# Out:
# array([ 0.23,  0.21,  0.29,  0.31,  0.24,  0.26,  0.22,  0.3 ,  0.2 ,
#         0.32,  0.33,  0.25,  0.35,  0.42,  0.28,  0.38,  0.7 ,  0.86,
#         0.71,  0.78,  0.96,  0.73,  0.8 ,  0.75,  0.74,  0.81,  0.59,
#         0.9 ,  0.91,  0.61,  0.77,  0.63,  0.76,  0.64,  0.72,  0.79,
#         0.58,  1.17,  0.6 ,  0.83,  0.54,  0.98,  0.52,  1.01,  0.53,
#         0.84,  0.51,  1.05,  0.55,  0.87,  1.  ,  0.57,  0.82,  1.04,
#         0.93,  1.2 ,  0.99,  0.34,  0.43,  0.36,  0.95,  0.89,  1.02,
#         0.97,  0.56,  0.85,  0.92,  1.27,  0.66,  1.12,  0.68,  1.03,
#         0.62,  1.22,  1.08,  0.88,  0.5 ,  1.19,  0.39,  0.65,  1.24,
#         1.5 ,  0.27,  0.41,  1.13,  1.06,  0.69,  0.4 ,  1.14,  0.94,
#         1.29,  1.52,  1.16,  1.21,  1.23,  1.09,  0.67,  1.11,  1.1 ,
#         1.18,  1.15,  1.25,  1.07,  1.28,  1.51,  0.37,  1.31,  1.26,
#         1.39,  1.44,  1.35,  1.3 ,  1.32,  1.41,  1.36,  1.45,  1.34,
# ...

# %%
iloc: select row by index(position) number
df_carat.iloc[3]
# Out:
#   File "<ipython-input-53-9dc6a1eb5ed8>", line 1
#     iloc: select row by index(position) number
#                    ^
# SyntaxError: invalid syntax

# %%
df['price'].mean()
# Out:
# 3932.799721913237

# %%
df_missing['price'].isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-eda6e70adb4e> in <module>()
# ----> 1 df_missing['price'].isnull()
#
# NameError: name 'df_missing' is not defined
